# %%
import frank_lab

# %%
fileroot = '../FrankLabData/';

# %%
import os
anim_dirs = [(d, os.path.join(fileroot,d)) for d in os.listdir(fileroot) if os.path.isdir(os.path.join(fileroot,d))]
print(anim_dirs)
# Out:
# [('Fra', '../FrankLabData/Fra')]

# %%
for (anim, dd) in anim_dirs:
    print(anim)
    print(dd)
# Out:
# Fra
# ../FrankLabData/Fra

# %%
task = {}
for (anim, dd) in anim_dirs:
    task[anim] = frank_lab.load_data(dd, datatype='task')
# Out:
# Loading fratask02.mat
# Loading fratask03.mat
# Loading fratask04.mat
# Loading fratask05.mat
# Loading fratask06.mat
# Loading fratask07.mat
# Loading fratask08.mat
# Loading fratask09.mat
# Loading fratask10.mat
# Loading fratask11.mat
# Loading fratask12.mat

# %%
task['Fra']
# Out:
#     Day  Epoch          type  exposure environment description  sleepnum  \
# 0     1      0         sleep       NaN         NaN         NaN       1.0
# 1     1      1           run       1.0      TrackB      TrackB       NaN
# 2     1      2         sleep       NaN         NaN         NaN       2.0
# 3     1      3           run       2.0      TrackB      TrackB       NaN
# 4     1      4         sleep       NaN         NaN         NaN       3.0
# 5     1      5           run      13.0      TrackA      TrackA       NaN
# 6     1      6         sleep       NaN         NaN         NaN       4.0
# 7     2      0         sleep       NaN         NaN         NaN       1.0
# 8     2      1           run       3.0      TrackB      TrackB       NaN
# 9     2      2         sleep       NaN         NaN         NaN       2.0
# 10    2      3           run       4.0      TrackB      TrackB       NaN
# 11    2      4         sleep       NaN         NaN         NaN       3.0
# 12    2      5           run      14.0      TrackA      TrackA       NaN
# 13    2      6         sleep       NaN         NaN         NaN       4.0
# 14    3      0  failed sleep       NaN         NaN         NaN       NaN
# 15    3      1           run       5.0      TrackB      TrackB       NaN
# 16    3      2         sleep       NaN         NaN         NaN       2.0
# 17    3      3           run       6.0      TrackB      TrackB       NaN
# 18    3      4         sleep       NaN         NaN         NaN       3.0
# 19    3      5           run      15.0      TrackA      TrackA       NaN
# 20    3      6         sleep       NaN         NaN         NaN       4.0
# 21    4      0         sleep       NaN         NaN         NaN       1.0
# 22    4      1           run       7.0      TrackB      TrackB       NaN
# 23    4      2         sleep       NaN         NaN         NaN       2.0
# 24    4      3           run       8.0      TrackB      TrackB       NaN
# 25    4      4         sleep       NaN         NaN         NaN       3.0
# 26    4      5           run      16.0      TrackA      TrackA       NaN
# 27    4      6         sleep       NaN         NaN         NaN       4.0
# 28    5      0         sleep       NaN         NaN         NaN       1.0
# 29    5      1           run       9.0      TrackB      TrackB       NaN
# ..  ...    ...           ...       ...         ...         ...       ...
# 47    7      5           run      19.0      TrackA      TrackA       NaN
# 48    7      6         sleep       NaN         NaN         NaN       4.0
# 49    8      0         sleep       NaN         NaN         NaN       1.0
# 50    8      1           run      15.0      TrackB      TrackB       NaN
# 51    8      2         sleep       NaN         NaN         NaN       2.0
# 52    8      3           run      16.0      TrackB      TrackB       NaN
# 53    8      4         sleep       NaN         NaN         NaN       3.0
# 54    8      5           run      20.0      TrackA      TrackA       NaN
# 55    8      6         sleep       NaN         NaN         NaN       4.0
# 56    9      0         sleep       NaN         NaN         NaN       1.0
# 57    9      1           run      17.0      TrackB      TrackB       NaN
# 58    9      2         sleep       NaN         NaN         NaN       2.0
# 59    9      3           run      18.0      TrackB      TrackB       NaN
# 60    9      4         sleep       NaN         NaN         NaN       3.0
# 61    9      5           run      21.0      TrackA      TrackA       NaN
# 62    9      6         sleep       NaN         NaN         NaN       4.0
# 63   10      0         sleep       NaN         NaN         NaN       1.0
# 64   10      1           run      19.0      TrackB      TrackB       NaN
# 65   10      2         sleep       NaN         NaN         NaN       2.0
# 66   10      3           run      20.0      TrackB      TrackB       NaN
# 67   10      4         sleep       NaN         NaN         NaN       3.0
# 68   10      5           run      22.0      TrackA      TrackA       NaN
# 69   10      6         sleep       NaN         NaN         NaN       4.0
# 70   11      0         sleep       NaN         NaN         NaN       1.0
# 71   11      1           run      21.0      TrackB      TrackB       NaN
# 72   11      2         sleep       NaN         NaN         NaN       2.0
# 73   11      3           run      22.0      TrackB      TrackB       NaN
# 74   11      4         sleep       NaN         NaN         NaN       3.0
# 75   11      5           run      23.0      TrackA      TrackA       NaN
# 76   11      6         sleep       NaN         NaN         NaN       4.0
#
#     dailyexposure  exposureday  experimentday  tracksexperienced  \
# 0             NaN          NaN            NaN                NaN
# 1             1.0          1.0            7.0                NaN
# 2             NaN          NaN            NaN                NaN
# 3             2.0          1.0            7.0                NaN
# 4             NaN          NaN            NaN                NaN
# 5             1.0          7.0            7.0                NaN
# 6             NaN          NaN            NaN                NaN
# 7             NaN          NaN            NaN                NaN
# 8             1.0          2.0            8.0                NaN
# 9             NaN          NaN            NaN                NaN
# 10            2.0          2.0            8.0                NaN
# 11            NaN          NaN            NaN                NaN
# 12            1.0          8.0            8.0                NaN
# 13            NaN          NaN            NaN                NaN
# 14            NaN          NaN            NaN                NaN
# 15            1.0          3.0            9.0                NaN
# 16            NaN          NaN            NaN                NaN
# 17            2.0          3.0            9.0                NaN
# 18            NaN          NaN            NaN                NaN
# 19            1.0          9.0            9.0                NaN
# 20            NaN          NaN            NaN                NaN
# 21            NaN          NaN            NaN                NaN
# 22            1.0          4.0           10.0                NaN
# 23            NaN          NaN            NaN                NaN
# 24            2.0          4.0           10.0                NaN
# 25            NaN          NaN            NaN                NaN
# 26            1.0         10.0           10.0                NaN
# 27            NaN          NaN            NaN                NaN
# 28            NaN          NaN            NaN                NaN
# 29            1.0          5.0           11.0                NaN
# ..            ...          ...            ...                ...
# 47            1.0         13.0           13.0                NaN
# 48            NaN          NaN            NaN                NaN
# 49            NaN          NaN            NaN                NaN
# 50            1.0          8.0           14.0                NaN
# 51            NaN          NaN            NaN                NaN
# 52            2.0          8.0           14.0                NaN
# 53            NaN          NaN            NaN                NaN
# 54            1.0         14.0           14.0                NaN
# 55            NaN          NaN            NaN                NaN
# 56            NaN          NaN            NaN                NaN
# 57            1.0          9.0           15.0                NaN
# 58            NaN          NaN            NaN                NaN
# 59            2.0          9.0           15.0                NaN
# 60            NaN          NaN            NaN                NaN
# 61            1.0         15.0           15.0                NaN
# 62            NaN          NaN            NaN                NaN
# 63            NaN          NaN            NaN                NaN
# 64            1.0         10.0           16.0                NaN
# 65            NaN          NaN            NaN                NaN
# 66            2.0         10.0           16.0                NaN
# 67            NaN          NaN            NaN                NaN
# 68            1.0         16.0           16.0                NaN
# 69            NaN          NaN            NaN                NaN
# 70            NaN          NaN            NaN                NaN
# 71            1.0         11.0           17.0                NaN
# 72            NaN          NaN            NaN                NaN
# 73            2.0         11.0           17.0                NaN
# 74            NaN          NaN            NaN                NaN
# 75            1.0         17.0           17.0                NaN
# 76            NaN          NaN            NaN                NaN
#
#     dailytracksexperienced
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN
# 6                      NaN
# 7                      NaN
# 8                      NaN
# 9                      NaN
# 10                     NaN
# 11                     NaN
# 12                     NaN
# 13                     NaN
# 14                     NaN
# 15                     NaN
# 16                     NaN
# 17                     NaN
# 18                     NaN
# 19                     NaN
# 20                     NaN
# 21                     NaN
# 22                     NaN
# 23                     NaN
# 24                     NaN
# 25                     NaN
# 26                     NaN
# 27                     NaN
# 28                     NaN
# 29                     NaN
# ..                     ...
# 47                     NaN
# 48                     NaN
# 49                     NaN
# 50                     NaN
# 51                     NaN
# 52                     NaN
# 53                     NaN
# 54                     NaN
# 55                     NaN
# 56                     NaN
# 57                     NaN
# 58                     NaN
# 59                     NaN
# 60                     NaN
# 61                     NaN
# 62                     NaN
# 63                     NaN
# 64                     NaN
# 65                     NaN
# 66                     NaN
# 67                     NaN
# 68                     NaN
# 69                     NaN
# 70                     NaN
# 71                     NaN
# 72                     NaN
# 73                     NaN
# 74                     NaN
# 75                     NaN
# 76                     NaN
#
# [77 rows x 12 columns]

# %%
task
# Out:
#     Day  Epoch          type  exposure environment description  sleepnum  \
# 0     1      0         sleep       NaN         NaN         NaN       1.0
# 1     1      1           run       1.0      TrackB      TrackB       NaN
# 2     1      2         sleep       NaN         NaN         NaN       2.0
# 3     1      3           run       2.0      TrackB      TrackB       NaN
# 4     1      4         sleep       NaN         NaN         NaN       3.0
# 5     1      5           run      13.0      TrackA      TrackA       NaN
# 6     1      6         sleep       NaN         NaN         NaN       4.0
# 7     2      0         sleep       NaN         NaN         NaN       1.0
# 8     2      1           run       3.0      TrackB      TrackB       NaN
# 9     2      2         sleep       NaN         NaN         NaN       2.0
# 10    2      3           run       4.0      TrackB      TrackB       NaN
# 11    2      4         sleep       NaN         NaN         NaN       3.0
# 12    2      5           run      14.0      TrackA      TrackA       NaN
# 13    2      6         sleep       NaN         NaN         NaN       4.0
# 14    3      0  failed sleep       NaN         NaN         NaN       NaN
# 15    3      1           run       5.0      TrackB      TrackB       NaN
# 16    3      2         sleep       NaN         NaN         NaN       2.0
# 17    3      3           run       6.0      TrackB      TrackB       NaN
# 18    3      4         sleep       NaN         NaN         NaN       3.0
# 19    3      5           run      15.0      TrackA      TrackA       NaN
# 20    3      6         sleep       NaN         NaN         NaN       4.0
# 21    4      0         sleep       NaN         NaN         NaN       1.0
# 22    4      1           run       7.0      TrackB      TrackB       NaN
# 23    4      2         sleep       NaN         NaN         NaN       2.0
# 24    4      3           run       8.0      TrackB      TrackB       NaN
# 25    4      4         sleep       NaN         NaN         NaN       3.0
# 26    4      5           run      16.0      TrackA      TrackA       NaN
# 27    4      6         sleep       NaN         NaN         NaN       4.0
# 28    5      0         sleep       NaN         NaN         NaN       1.0
# 29    5      1           run       9.0      TrackB      TrackB       NaN
# ..  ...    ...           ...       ...         ...         ...       ...
# 47    7      5           run      19.0      TrackA      TrackA       NaN
# 48    7      6         sleep       NaN         NaN         NaN       4.0
# 49    8      0         sleep       NaN         NaN         NaN       1.0
# 50    8      1           run      15.0      TrackB      TrackB       NaN
# 51    8      2         sleep       NaN         NaN         NaN       2.0
# 52    8      3           run      16.0      TrackB      TrackB       NaN
# 53    8      4         sleep       NaN         NaN         NaN       3.0
# 54    8      5           run      20.0      TrackA      TrackA       NaN
# 55    8      6         sleep       NaN         NaN         NaN       4.0
# 56    9      0         sleep       NaN         NaN         NaN       1.0
# 57    9      1           run      17.0      TrackB      TrackB       NaN
# 58    9      2         sleep       NaN         NaN         NaN       2.0
# 59    9      3           run      18.0      TrackB      TrackB       NaN
# 60    9      4         sleep       NaN         NaN         NaN       3.0
# 61    9      5           run      21.0      TrackA      TrackA       NaN
# 62    9      6         sleep       NaN         NaN         NaN       4.0
# 63   10      0         sleep       NaN         NaN         NaN       1.0
# 64   10      1           run      19.0      TrackB      TrackB       NaN
# 65   10      2         sleep       NaN         NaN         NaN       2.0
# 66   10      3           run      20.0      TrackB      TrackB       NaN
# 67   10      4         sleep       NaN         NaN         NaN       3.0
# 68   10      5           run      22.0      TrackA      TrackA       NaN
# 69   10      6         sleep       NaN         NaN         NaN       4.0
# 70   11      0         sleep       NaN         NaN         NaN       1.0
# 71   11      1           run      21.0      TrackB      TrackB       NaN
# 72   11      2         sleep       NaN         NaN         NaN       2.0
# 73   11      3           run      22.0      TrackB      TrackB       NaN
# 74   11      4         sleep       NaN         NaN         NaN       3.0
# 75   11      5           run      23.0      TrackA      TrackA       NaN
# 76   11      6         sleep       NaN         NaN         NaN       4.0
#
#     dailyexposure  exposureday  experimentday  tracksexperienced  \
# 0             NaN          NaN            NaN                NaN
# 1             1.0          1.0            7.0                NaN
# 2             NaN          NaN            NaN                NaN
# 3             2.0          1.0            7.0                NaN
# 4             NaN          NaN            NaN                NaN
# 5             1.0          7.0            7.0                NaN
# 6             NaN          NaN            NaN                NaN
# 7             NaN          NaN            NaN                NaN
# 8             1.0          2.0            8.0                NaN
# 9             NaN          NaN            NaN                NaN
# 10            2.0          2.0            8.0                NaN
# 11            NaN          NaN            NaN                NaN
# 12            1.0          8.0            8.0                NaN
# 13            NaN          NaN            NaN                NaN
# 14            NaN          NaN            NaN                NaN
# 15            1.0          3.0            9.0                NaN
# 16            NaN          NaN            NaN                NaN
# 17            2.0          3.0            9.0                NaN
# 18            NaN          NaN            NaN                NaN
# 19            1.0          9.0            9.0                NaN
# 20            NaN          NaN            NaN                NaN
# 21            NaN          NaN            NaN                NaN
# 22            1.0          4.0           10.0                NaN
# 23            NaN          NaN            NaN                NaN
# 24            2.0          4.0           10.0                NaN
# 25            NaN          NaN            NaN                NaN
# 26            1.0         10.0           10.0                NaN
# 27            NaN          NaN            NaN                NaN
# 28            NaN          NaN            NaN                NaN
# 29            1.0          5.0           11.0                NaN
# ..            ...          ...            ...                ...
# 47            1.0         13.0           13.0                NaN
# 48            NaN          NaN            NaN                NaN
# 49            NaN          NaN            NaN                NaN
# 50            1.0          8.0           14.0                NaN
# 51            NaN          NaN            NaN                NaN
# 52            2.0          8.0           14.0                NaN
# 53            NaN          NaN            NaN                NaN
# 54            1.0         14.0           14.0                NaN
# 55            NaN          NaN            NaN                NaN
# 56            NaN          NaN            NaN                NaN
# 57            1.0          9.0           15.0                NaN
# 58            NaN          NaN            NaN                NaN
# 59            2.0          9.0           15.0                NaN
# 60            NaN          NaN            NaN                NaN
# 61            1.0         15.0           15.0                NaN
# 62            NaN          NaN            NaN                NaN
# 63            NaN          NaN            NaN                NaN
# 64            1.0         10.0           16.0                NaN
# 65            NaN          NaN            NaN                NaN
# 66            2.0         10.0           16.0                NaN
# 67            NaN          NaN            NaN                NaN
# 68            1.0         16.0           16.0                NaN
# 69            NaN          NaN            NaN                NaN
# 70            NaN          NaN            NaN                NaN
# 71            1.0         11.0           17.0                NaN
# 72            NaN          NaN            NaN                NaN
# 73            2.0         11.0           17.0                NaN
# 74            NaN          NaN            NaN                NaN
# 75            1.0         17.0           17.0                NaN
# 76            NaN          NaN            NaN                NaN
#
#     dailytracksexperienced
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN
# 6                      NaN
# 7                      NaN
# 8                      NaN
# 9                      NaN
# 10                     NaN
# 11                     NaN
# 12                     NaN
# 13                     NaN
# 14                     NaN
# 15                     NaN
# 16                     NaN
# 17                     NaN
# 18                     NaN
# 19                     NaN
# 20                     NaN
# 21                     NaN
# 22                     NaN
# 23                     NaN
# 24                     NaN
# 25                     NaN
# 26                     NaN
# 27                     NaN
# 28                     NaN
# 29                     NaN
# ..                     ...
# 47                     NaN
# 48                     NaN
# 49                     NaN
# 50                     NaN
# 51                     NaN
# 52                     NaN
# 53                     NaN
# 54                     NaN
# 55                     NaN
# 56                     NaN
# 57                     NaN
# 58                     NaN
# 59                     NaN
# 60                     NaN
# 61                     NaN
# 62                     NaN
# 63                     NaN
# 64                     NaN
# 65                     NaN
# 66                     NaN
# 67                     NaN
# 68                     NaN
# 69                     NaN
# 70                     NaN
# 71                     NaN
# 72                     NaN
# 73                     NaN
# 74                     NaN
# 75                     NaN
# 76                     NaN
#
# [77 rows x 12 columns]

# %%
task[task['type']=='run']
# Out:
#     Day  Epoch type  exposure environment description  sleepnum  \
# 1     1      1  run       1.0      TrackB      TrackB       NaN
# 3     1      3  run       2.0      TrackB      TrackB       NaN
# 5     1      5  run      13.0      TrackA      TrackA       NaN
# 8     2      1  run       3.0      TrackB      TrackB       NaN
# 10    2      3  run       4.0      TrackB      TrackB       NaN
# 12    2      5  run      14.0      TrackA      TrackA       NaN
# 15    3      1  run       5.0      TrackB      TrackB       NaN
# 17    3      3  run       6.0      TrackB      TrackB       NaN
# 19    3      5  run      15.0      TrackA      TrackA       NaN
# 22    4      1  run       7.0      TrackB      TrackB       NaN
# 24    4      3  run       8.0      TrackB      TrackB       NaN
# 26    4      5  run      16.0      TrackA      TrackA       NaN
# 29    5      1  run       9.0      TrackB      TrackB       NaN
# 31    5      3  run      10.0      TrackB      TrackB       NaN
# 33    5      5  run      17.0      TrackA      TrackA       NaN
# 36    6      1  run      11.0      TrackB      TrackB       NaN
# 38    6      3  run      12.0      TrackB      TrackB       NaN
# 40    6      5  run      18.0      TrackA      TrackA       NaN
# 43    7      1  run      13.0      TrackB      TrackB       NaN
# 45    7      3  run      14.0      TrackB      TrackB       NaN
# 47    7      5  run      19.0      TrackA      TrackA       NaN
# 50    8      1  run      15.0      TrackB      TrackB       NaN
# 52    8      3  run      16.0      TrackB      TrackB       NaN
# 54    8      5  run      20.0      TrackA      TrackA       NaN
# 57    9      1  run      17.0      TrackB      TrackB       NaN
# 59    9      3  run      18.0      TrackB      TrackB       NaN
# 61    9      5  run      21.0      TrackA      TrackA       NaN
# 64   10      1  run      19.0      TrackB      TrackB       NaN
# 66   10      3  run      20.0      TrackB      TrackB       NaN
# 68   10      5  run      22.0      TrackA      TrackA       NaN
# 71   11      1  run      21.0      TrackB      TrackB       NaN
# 73   11      3  run      22.0      TrackB      TrackB       NaN
# 75   11      5  run      23.0      TrackA      TrackA       NaN
#
#     dailyexposure  exposureday  experimentday  tracksexperienced  \
# 1             1.0          1.0            7.0                NaN
# 3             2.0          1.0            7.0                NaN
# 5             1.0          7.0            7.0                NaN
# 8             1.0          2.0            8.0                NaN
# 10            2.0          2.0            8.0                NaN
# 12            1.0          8.0            8.0                NaN
# 15            1.0          3.0            9.0                NaN
# 17            2.0          3.0            9.0                NaN
# 19            1.0          9.0            9.0                NaN
# 22            1.0          4.0           10.0                NaN
# 24            2.0          4.0           10.0                NaN
# 26            1.0         10.0           10.0                NaN
# 29            1.0          5.0           11.0                NaN
# 31            2.0          5.0           11.0                NaN
# 33            1.0         11.0           11.0                NaN
# 36            1.0          6.0           12.0                NaN
# 38            2.0          6.0           12.0                NaN
# 40            1.0         12.0           12.0                NaN
# 43            1.0          7.0           13.0                NaN
# 45            2.0          7.0           13.0                NaN
# 47            1.0         13.0           13.0                NaN
# 50            1.0          8.0           14.0                NaN
# 52            2.0          8.0           14.0                NaN
# 54            1.0         14.0           14.0                NaN
# 57            1.0          9.0           15.0                NaN
# 59            2.0          9.0           15.0                NaN
# 61            1.0         15.0           15.0                NaN
# 64            1.0         10.0           16.0                NaN
# 66            2.0         10.0           16.0                NaN
# 68            1.0         16.0           16.0                NaN
# 71            1.0         11.0           17.0                NaN
# 73            2.0         11.0           17.0                NaN
# 75            1.0         17.0           17.0                NaN
#
#     dailytracksexperienced
# 1                      NaN
# 3                      NaN
# 5                      NaN
# 8                      NaN
# 10                     NaN
# 12                     NaN
# 15                     NaN
# 17                     NaN
# 19                     NaN
# 22                     NaN
# 24                     NaN
# 26                     NaN
# 29                     NaN
# 31                     NaN
# 33                     NaN
# 36                     NaN
# 38                     NaN
# 40                     NaN
# 43                     NaN
# 45                     NaN
# 47                     NaN
# 50                     NaN
# 52                     NaN
# 54                     NaN
# 57                     NaN
# 59                     NaN
# 61                     NaN
# 64                     NaN
# 66                     NaN
# 68                     NaN
# 71                     NaN
# 73                     NaN
# 75                     NaN

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set(rc={'figure.figsize': (12, 4),'lines.linewidth': 2, 'font.size': 18, 'axes.labelsize': 16, 'legend.fontsize': 12, 'ytick.labelsize': 12, 'xtick.labelsize': 12 })
sns.set_style('white')

# %%
tt = task[task['type']=='run']
plt.plot(tt['Day']*3+(tt['Epoch']/2), tt['exposure'],'-.')

# %%
[cellinfo,rawcellinfo] = frank_lab.load_data(fileroot, datatype='cellinfo')
# Out:
# Loading fracellinfo00.mat

# %%
cellinfo
# Out:
#                     type hemisphere spikewidth  nearCA2  Cell  Tetrode  \
# (1, 0, 0, 0)   principal      right    6.65957      1.0     0        0
# (1, 0, 0, 1)   principal      right    8.10829      1.0     1        0
# (1, 0, 1, 0)   principal      right    8.23988      1.0     0        1
# (1, 0, 1, 1)   principal      right    8.40681      1.0     1        1
# (1, 0, 1, 2)   principal      right    9.32111      1.0     2        1
# (1, 0, 1, 3)   principal      right    8.88068      1.0     3        1
# (1, 0, 20, 0)  principal       left    6.92239      1.0     0       20
# (1, 0, 26, 0)  principal      right    7.46446      1.0     0       26
# (1, 0, 26, 1)  principal      right    8.24167      1.0     1       26
# (1, 0, 26, 2)  principal      right    8.24666      1.0     2       26
# (1, 0, 28, 0)  principal      right     8.2207      0.0     0       28
# (1, 0, 28, 1)  principal      right    7.44135      0.0     1       28
# (1, 0, 7, 0)   principal      right    7.77613      0.0     0        7
# (1, 0, 7, 1)       inter      right    5.33747      0.0     1        7
# (1, 1, 0, 0)   principal      right    6.65957      1.0     0        0
# (1, 1, 0, 1)   principal      right    8.10829      1.0     1        0
# (1, 1, 1, 0)   principal      right         []      1.0     0        1
# (1, 1, 1, 1)   principal      right    8.40681      1.0     1        1
# (1, 1, 1, 2)   principal      right    9.32111      1.0     2        1
# (1, 1, 1, 3)   principal      right    8.88068      1.0     3        1
# (1, 1, 20, 0)  principal       left    6.92239      1.0     0       20
# (1, 1, 26, 0)  principal      right    7.46446      1.0     0       26
# (1, 1, 26, 1)  principal      right    8.24167      1.0     1       26
# (1, 1, 26, 2)  principal      right    8.24666      1.0     2       26
# (1, 1, 28, 0)  principal      right     8.2207      0.0     0       28
# (1, 1, 28, 1)  principal      right    7.44135      0.0     1       28
# (1, 1, 3, 0)   principal      right    10.1416      0.0     0        3
# (1, 1, 7, 0)   principal      right    7.77613      0.0     0        7
# (1, 1, 7, 1)       inter      right    5.33747      0.0     1        7
# (1, 2, 0, 0)   principal      right    6.65957      1.0     0        0
# ...                  ...        ...        ...      ...   ...      ...
# (9, 6, 5, 0)   principal      right     9.7073      1.0     0        5
# (9, 6, 5, 1)   principal      right    7.72332      1.0     1        5
# (9, 6, 5, 2)   principal      right    6.72481      1.0     2        5
# (9, 6, 5, 3)   principal      right     7.4052      1.0     3        5
# (9, 6, 5, 4)   principal      right    9.95634      1.0     4        5
# (9, 6, 5, 5)   principal      right     7.9009      1.0     5        5
# (9, 6, 5, 6)   principal      right    8.83942      1.0     6        5
# (9, 6, 5, 7)   principal      right    9.57493      1.0     7        5
# (9, 6, 5, 8)   principal      right    6.89414      1.0     8        5
# (9, 6, 5, 9)   principal      right    7.31938      1.0     9        5
# (9, 6, 6, 0)   principal      right    8.86159      0.0     0        6
# (9, 6, 6, 1)   principal      right     7.9751      0.0     1        6
# (9, 6, 7, 0)       inter      right     5.5609      0.0     0        7
# (9, 6, 7, 1)   principal      right    7.14143      0.0     1        7
# (9, 6, 7, 2)   principal      right    8.44751      0.0     2        7
# (9, 6, 7, 3)   principal      right    8.90201      0.0     3        7
# (9, 6, 7, 4)   principal      right    8.92223      0.0     4        7
# (9, 6, 8, 0)   principal      right    7.75892      1.0     0        8
# (9, 6, 8, 1)   principal      right    7.82981      1.0     1        8
# (9, 6, 8, 2)   principal      right    6.80895      1.0     2        8
# (9, 6, 8, 3)   principal      right    8.09199      1.0     3        8
# (9, 6, 8, 4)   principal      right    8.87529      1.0     4        8
# (9, 6, 8, 5)   principal      right    7.64485      1.0     5        8
# (9, 6, 9, 0)   principal      right    7.92281      1.0     0        9
# (9, 6, 9, 1)   principal      right    6.39684      1.0     1        9
# (9, 6, 9, 2)   principal      right    5.80694      1.0     2        9
# (9, 6, 9, 3)   principal      right    8.21897      1.0     3        9
# (9, 6, 9, 4)   principal      right    9.62487      1.0     4        9
# (9, 6, 9, 5)   principal      right    9.40374      1.0     5        9
# (9, 6, 9, 6)   principal      right     9.2542      1.0     6        9
#
#                 subarea  Epoch area  numspikes  Day   meanrate
# (1, 0, 0, 0)        CA2      0  CA2       31.0    1   0.037394
# (1, 0, 0, 1)        CA2      0  CA2      399.0    1   0.481303
# (1, 0, 1, 0)   CA2-CA3a      0  CA2       37.0    1   0.044632
# (1, 0, 1, 1)   CA2-CA3a      0  CA2      182.0    1   0.219542
# (1, 0, 1, 2)   CA2-CA3a      0  CA2       49.0    1   0.059107
# (1, 0, 1, 3)   CA2-CA3a      0  CA2       50.0    1   0.060314
# (1, 0, 20, 0)  CA2-CA3a      0  CA2       31.0    1   0.037394
# (1, 0, 26, 0)  CA2-CA3a      0  CA2      269.0    1   0.324487
# (1, 0, 26, 1)  CA2-CA3a      0  CA2     1040.0    1   1.254524
# (1, 0, 26, 2)  CA2-CA3a      0  CA2       27.0    1   0.032569
# (1, 0, 28, 0)      CA3b      0  CA3       64.0    1   0.077201
# (1, 0, 28, 1)      CA3b      0  CA3       18.0    1   0.021713
# (1, 0, 7, 0)       CA3b      0  CA3      100.0    1   0.120627
# (1, 0, 7, 1)       CA3b      0  CA3    20756.0    1  25.037394
# (1, 1, 0, 0)        CA2      1  CA2        9.0    1   0.009698
# (1, 1, 0, 1)        CA2      1  CA2     2624.0    1   2.827586
# (1, 1, 1, 0)   CA2-CA3a      1  CA2        0.0    1   0.000000
# (1, 1, 1, 1)   CA2-CA3a      1  CA2      276.0    1   0.297414
# (1, 1, 1, 2)   CA2-CA3a      1  CA2      281.0    1   0.302802
# (1, 1, 1, 3)   CA2-CA3a      1  CA2        1.0    1   0.001078
# (1, 1, 20, 0)  CA2-CA3a      1  CA2       21.0    1   0.022629
# (1, 1, 26, 0)  CA2-CA3a      1  CA2        1.0    1   0.001078
# (1, 1, 26, 1)  CA2-CA3a      1  CA2       89.0    1   0.095905
# (1, 1, 26, 2)  CA2-CA3a      1  CA2        1.0    1   0.001078
# (1, 1, 28, 0)      CA3b      1  CA3        1.0    1   0.001078
# (1, 1, 28, 1)      CA3b      1  CA3        2.0    1   0.002155
# (1, 1, 3, 0)       CA3b      1  CA3      579.0    1   0.623922
# (1, 1, 7, 0)       CA3b      1  CA3     2019.0    1   2.175647
# (1, 1, 7, 1)       CA3b      1  CA3    28624.0    1  30.844828
# (1, 2, 0, 0)        CA2      2  CA2       75.0    1   0.052669
# ...                 ...    ...  ...        ...  ...        ...
# (9, 6, 5, 0)       CA1c      6  CA1      434.0    9   0.346922
# (9, 6, 5, 1)       CA1c      6  CA1     1014.0    9   0.810552
# (9, 6, 5, 2)       CA1c      6  CA1      113.0    9   0.090328
# (9, 6, 5, 3)       CA1c      6  CA1       95.0    9   0.075939
# (9, 6, 5, 4)       CA1c      6  CA1      379.0    9   0.302958
# (9, 6, 5, 5)       CA1c      6  CA1      441.0    9   0.352518
# (9, 6, 5, 6)       CA1c      6  CA1      397.0    9   0.317346
# (9, 6, 5, 7)       CA1c      6  CA1      770.0    9   0.615508
# (9, 6, 5, 8)       CA1c      6  CA1      106.0    9   0.084732
# (9, 6, 5, 9)       CA1c      6  CA1       92.0    9   0.073541
# (9, 6, 6, 0)       CA3b      6  CA3     1123.0    9   0.897682
# (9, 6, 6, 1)       CA3b      6  CA3       36.0    9   0.028777
# (9, 6, 7, 0)       CA3b      6  CA3    44918.0    9  35.905675
# (9, 6, 7, 1)       CA3b      6  CA3       45.0    9   0.035971
# (9, 6, 7, 2)       CA3b      6  CA3      238.0    9   0.190248
# (9, 6, 7, 3)       CA3b      6  CA3      461.0    9   0.368505
# (9, 6, 7, 4)       CA3b      6  CA3       75.0    9   0.059952
# (9, 6, 8, 0)       CA1c      6  CA1      335.0    9   0.267786
# (9, 6, 8, 1)       CA1c      6  CA1      182.0    9   0.145484
# (9, 6, 8, 2)       CA1c      6  CA1      271.0    9   0.216627
# (9, 6, 8, 3)       CA1c      6  CA1      683.0    9   0.545963
# (9, 6, 8, 4)       CA1c      6  CA1      246.0    9   0.196643
# (9, 6, 8, 5)       CA1c      6  CA1      161.0    9   0.128697
# (9, 6, 9, 0)       CA1c      6  CA1      210.0    9   0.167866
# (9, 6, 9, 1)       CA1c      6  CA1      228.0    9   0.182254
# (9, 6, 9, 2)       CA1c      6  CA1       98.0    9   0.078337
# (9, 6, 9, 3)       CA1c      6  CA1      381.0    9   0.304556
# (9, 6, 9, 4)       CA1c      6  CA1      497.0    9   0.397282
# (9, 6, 9, 5)       CA1c      6  CA1      214.0    9   0.171063
# (9, 6, 9, 6)       CA1c      6  CA1      655.0    9   0.523581
#
# [4177 rows x 12 columns]
